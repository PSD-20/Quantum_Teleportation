# %%
import pickle
from utils import *

# %%
with open("Variables.pkl", "rb") as f:
    data = pickle.load(f)

# See all variable names
print("Variables in pickle file:", list(data.keys()))
# Out:
# Variables in pickle file: ['mltpl_countsa', 'mltpl_countsb', 'batch_fdlty', 'batch_state_fdlty', 'n_batch']

# %%
#Variable from run.ipynb

counta = data['counta']
countb = data['countb']
fdlty = data['fdlty']
state_fdlty = data['state_fdlty']
n = data['n']

# %%
#Variable from run_batch.ipynb

mltpl_countsa = data['mltpl_countsa'] 
mltpl_countsb = data['mltpl_countsb'] 
batch_fdlty = data['batch_fdlty']
batch_state_fdlty = data['batch_state_fdlty']
n_batch = data['n_batch']

# %%
#Run the results from run.ipynb

plot_counts(counta, n), plot_counts(countb, n)

# %%
#Run the results from run_batch.ipynb

plot_batch_counts(batch_fdlty, batch_state_fdlty)
